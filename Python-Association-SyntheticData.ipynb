# %% [markdown]
# <div style="text-align: center; margin-bottom: 25px;  padding: 20px; border-radius: 10px;">
#
# <h1 style= "font-weight: bold; font-size: 2.5em;">🐍 Condition Association Template w/ Example Data</h1>
#
# </div>

# %% [markdown]
# <div style="text-align: center;">
#
# <h1 style="color: black; font-weight: bold;">Table of Contents</h1><a class='anchor' id='top'></a>
#
# <table style="margin: auto;">
#     <tr>
#         <td style="text-align: left;"><a href="#pssection_1">1. Introduction</a></td>
#     </tr>
#     <tr>
#         <td style="text-align: left;"><a href="#pssection_2">2. Import Libraries</a></td>
#     </tr>
#     <tr>
#         <td style="text-align: left;"><a href="#pssection_3">3. Import Data</a></td>
#     </tr>
#     <tr>
#         <td style="text-align: left;"><a href="#pssection_4">4. Relabel Data Frames</a></td>
#     </tr>
#     <tr>
#         <td style="text-align: left;"><a href="#pssection_5">5. Creating a Column for the Outcome</a></td>
#     </tr>
#     <tr>
#         <td style="text-align: left;"><a href="#pssection_6">6. Creating a Column for the Predictor</a></td>
#     </tr>
#     <tr>
#         <td style="text-align: left;"><a href="#pssection_7">7. Join the Data Frames</a></td>
#     </tr>
#     <tr>
#         <td style="text-align: left;"><a href="#pssection_8">8. Replace NAs</a></td>
#     </tr>
#     <tr>
#         <td style="text-align: left;"><a href="#pssection_9">9. Factor the Categorical Variables</a></td>
#     </tr>
#     <tr>
#         <td style="text-align: left;"><a href="#pssection_10">10. Calculate Age</a></td>
#     </tr>
#     <tr>
#         <td style="text-align: left;"><a href="#pssection_11">11. Explore Cleaned Data</a></td>
#     </tr>
#     <tr>
#         <td style="text-align: left; padding-left: 20px;"><a href="#pssubsection_11_1">11.1 Numerical Summary</a></td>
#     </tr>
#     <tr>
#         <td style="text-align: left; padding-left: 20px;"><a href="#pssubsection_11_2">11.2 Graphical Summary</a></td>
#     </tr>
#     <tr>
#         <td style="text-align: left; padding-left: 40px;"><a href="#pssubsection_11_2_1">11.2.1 Density/Histogram Plot</a></td>
#     </tr>
#     <tr>
#         <td style="text-align: left; padding-left: 40px;"><a href="#pssubsection_11_2_2">11.2.2 Bar Plot</a></td>
#     </tr>
#     <tr>
#         <td style="text-align: left;"><a href="#pssection_12">12. Statistical Analysis</a></td>
#     </tr>
#     <tr>
#         <td style="text-align: left; padding-left: 20px;"><a href="#pssubsection_12_1">12.1 Pearson's Chi-Square Test</a></td>
#     </tr>
#     <tr>
#         <td style="text-align: left; padding-left: 20px;"><a href="#pssubsection_12_2">12.2 Variance Test and T-Test</a></td>
#     </tr>
#     <tr>
#         <td style="text-align: left; padding-left: 20px;"><a href="#pssubsection_12_3">12.3 Logistic Regressions</a></td>
#     </tr>
#     <tr>
#         <td style="text-align: left; padding-left: 40px;"><a href="#pssubsection_12_3_1">12.3.1 Unadjusted Logistic Regression</a></td>
#     </tr>
#     <tr>
#         <td style="text-align: left; padding-left: 40px;"><a href="#pssubsection_12_3_2">12.3.2 Unadjusted Odds Ratio and Confidence Interval</a></td>
#     </tr>
#     <tr>
#         <td style="text-align: left; padding-left: 40px;"><a href="#pssubsection_12_3_3">12.3.3 Adjusted Logistic Regression</a></td>
#     </tr>
#     <tr>
#         <td style="text-align: left; padding-left: 40px;"><a href="#pssubsection_12_3_4">12.3.4 Adjusted Odds Ratio and Confidence Interval</a></td>
#     </tr>
#     <tr>
#         <td style="text-align: left; padding-left: 40px;"><a href="#pssubsection_12_3_5">12.3.5 Summary of Logistic Regressions</a></td>
#     </tr>
#     <tr>
#         <td style="text-align: left; padding-left: 40px;"><a href="#pssubsection_12_3_6">12.3.6 Forest Plot</a></td>
#     </tr>
# </table>
#
# </div>

# %% [markdown]
# <div style="text-align: center; margin-bottom: 25px; background-color: #E6FFE6; padding: 10px; border-radius: 10px;">
#
# <a id='pssection_1'></a>
#
# <h1 style="color: #2E86C1; font-weight: bold;">1. Introduction 👋</h1>
#
# </div>
#
#
# <div style="text-align: center; margin: 0 auto; width: 80%; border: 2px solid #2E86C1; padding: 20px; border-radius: 10px; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#
# **Welcome to the Condition Association Code Template tailored for the All of Us (AoU) data!** Our goal is to guide you through analyzing the relationship between two conditions using AoU data. This template offers a comprehensive pathway and code samples to simplify your analysis. It's designed for both beginners and experienced analysts. Please follow the [AoU Condition Association Code Template Instructions](https://drive.google.com/file/d/1gjwjX3Vq6GVTUkpQM_4PanhTBQScL8Fp/view?usp=sharing) to build your cohorts and data frames for this template. This is the only way to guarantee consistent results.
#
# **To upload these templates to a workspace in the All of Us Researcher Workbench, please follow these [instructions](https://support.researchallofus.org/hc/en-us/articles/360042684051-Are-external-coding-files-able-to-be-imported-for-analysis-)**
#
# <font color='red' size="4"><strong>Note: Each section contains important information. Please read them carefully! </strong></font>
#
# <br>
#
# <h2 style="color: #2E86C1; text-decoration: underline; font-weight: bold;">Learning Objectives:</h2>
#
# <ul style="list-style-position: inside; text-align: left; display: inline-block;">
#     <li><strong>Set up Python in Jupyter and load required libraries and packages.</strong></li>
#     <li><strong>Load and prepare dataframes for analysis.</strong></li>
#     <li><strong>Produce a data summary table.</strong></li>
#     <li><strong>Create and interpret visualizations, such as bar charts, box plots, and density plots.</strong></li>
#     <li><strong>Conduct and interpret various tests and regressions:</strong>
#         <ul style="padding-left: 40px;">
#             <li><strong>Use the Chi-square test for categorical data.</strong></li>
#             <li><strong>Apply the T-test for comparing means.</strong></li>
#             <li><strong>Perform unadjusted logistic regression for binary outcomes with one predictor.</strong></li>
#             <li><strong>Run adjusted logistic regression with multiple predictors.</strong></li>
#         </ul>
#     </li>
#     <li><strong>Draw conclusions from your analysis, considering the implications and limitations.</strong></li>
# </ul>
#
# </div>

# %% [markdown]
# ---
# <div style="text-align: center; margin-bottom: 25px; background-color: #E6FFE6; padding: 10px; border-radius: 10px;">
#
# <a id='pssection_2'></a>
#
# <h1 style="color: #2E86C1; font-weight: bold;">2. Import Libraries 📚</h1>
#
# </div>
#
# <div style="border: 2px solid #2E86C1; padding: 20px; border-radius: 10px; margin: 20px 0; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#
# <div style="font-size: 17px; text-align: center; width: 80%; margin: 20px auto; line-height: 1.6; color: #333;">
#
# The following code block checks for each listed package. If not already installed, you will need to install the package using `!pip install package`.
#
# <strong>Automatically Imported by All of Us:</strong> `pandas`, `os`
#
# <strong>Require Manual Import:</strong> `random`, `datetime`, `tableone`, `scipy.stats`, `seaborn`, `matplotlib.pyplot`, `warnings`, `numpy`, `statsmodels.formula.api`, `forestplot`
#
# </div>
#
# <div style="text-align: center; margin: 20px auto; width: 80%; font-size: 17px; background-color: #e6f2ff; padding: 15px; border-radius: 6px; line-height: 1.6; border: 1px solid #2E86C1;">
# <b>Note:</b> Packages are auto-imported only when using the DatasetBuilder to export dataframes. Without the DatasetBuilder, no packages are imported automatically.
# </div>
#
# </div>

# %%
import pandas
import random
from random import choices
from datetime import datetime
from tableone import TableOne
from scipy.stats import chi2_contingency
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import numpy as np
import scipy.stats as stats
import statsmodels.formula.api as smf
import forestplot as fp
# Out:
# C:\Users\HSLSuser\AppData\Local\Temp\ipykernel_9096\605884924.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas

# %%
# Uncomment below to install packages, error message will appear if package not installed
#!pip install package

# %% [markdown]
# ---
# <div style="text-align: center; margin-bottom: 25px; background-color: #E6FFE6; padding: 10px; border-radius: 10px;">
#
# <a id='pssection_3'></a>
#
# <h1 style="color: #2E86C1; font-weight: bold;">3. Import Data 🗃️</h1>
#
# </div>
#
# <div style="border: 2px solid #2E86C1; padding: 20px; border-radius: 10px; margin: 20px 0; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#
# <div style="font-size: 17px; text-align: center; width: 80%; margin: 20px auto; line-height: 1.6; color: #333;">
#
# This section simulates the process of importing All of Us datasets. In the actual AoU Researcher Workbench, data is imported using the DatasetBuilder which builds the SQL code. For the Python kernel, there is one code cell generated for each dataset. For the <strong>three datasets</strong> you need in this analysis, expect a total of <strong>three code cells</strong>.
#
# <font color='red' size="4"><strong>Note: The AoU data frames will be imported to the bottom of the code template. You need to move them up to this section! </strong></font>
#
# **How to do this:** Select the first imported cell, it will highlight blue. While holding down `Shift`, scroll to the last imported cell and click on it. All three cells should highlight blue. Hit the up arrow ⬆ in the toolbar and move the cells to this section. You can keep track of this in the Table of Contents by watching the yellow box move from section to section. Once it reaches the correct section (<font color='blue' size="4"><strong>3. Import Data</strong></font>), you can stop moving the cells. Don't forget to rename the datasets in Section 4!
#
# </div>
#
# </div>

# %%
random.seed(12)

def generate_random_data(start_id, n):
    person_id = list(range(start_id, start_id+n))
  
    sex_at_birth = random.choices(['Male', 'Female'], k=n)

    start_date = datetime(1945, 1, 1)
    end_date = datetime(2002, 12, 31)
  
    random_dates = []
    for i in range(n):
        random_date = start_date + (end_date - start_date) * random.random()
        random_dates.append(random_date.strftime('%Y-%m-%d %H:%M:%S UTC'))

    race = random.choices(['Black or African American', 'White', 'Asian'], k=n)
  
    ethnicity = random.choices(['Hispanic or Latino', 'Not Hispanic or Latino'], k=n)

    data = pandas.DataFrame({
        'person_id': person_id, 
        'sex_at_birth': sex_at_birth,
        'date_of_birth': random_dates,
        'race': race,
        'ethnicity': ethnicity})


    # Assuming df is your DataFrame and 'date_column' is the name of your column
    data['date_of_birth'] = pandas.to_datetime(data['date_of_birth'])

  
    return data

dataset_12345678_person_df = generate_random_data(1, 300)
dataset_23456789_person_df = generate_random_data(301, 1000)

# Combined person IDs from df1 and df2
case_ids = list(dataset_12345678_person_df['person_id']) 
control_ids = list(dataset_23456789_person_df['person_id'])

# Randomly sample from the combined person IDs 
# For 470 occurrences (adjust as needed)
disease_occurrences_1 =  random.sample(case_ids, k=178) 
disease_occurrences_2 =  random.sample(control_ids, k=112)

disease_occurrences = disease_occurrences_1 + disease_occurrences_2

# Create the dataframe
dataset_34567890_person_df = pandas.DataFrame({
  'person_id': disease_occurrences
})

# %% [markdown]
# ---
# <div style="text-align: center; margin-bottom: 25px; background-color: #E6FFE6; padding: 10px; border-radius: 10px;">
#
# <a id='pssection_4'></a>
#
# <h1 style="color: #2E86C1; font-weight: bold;">4. Relabel Data Frames 🏷️</h1>
#
# </div>
#
# <div style="border: 2px solid #2E86C1; padding: 20px; border-radius: 10px; margin: 20px 0; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#
# <div style="font-size: 17px; text-align: center; width: 80%; margin: 20px auto; line-height: 1.6; color: #333;">
#
# In this section, you'll be renaming the AoU data frames. When datasets are imported into the notebook using the DatasetBuilder, they're named in the format: <code>dataset_12345678_domain_df</code>. The <code>domain</code> corresponds to the type of concept set linked to your cohort (i.e `person` corresponds to the **Demographics** prepackaged concept set).
#
# </div>
#
# </div>

# %%
# Rename data frames
case_df = dataset_12345678_person_df
control_df = dataset_23456789_person_df
condition_df = dataset_34567890_person_df

# The outcome condition used to build case and control cohorts
condition_1_name = "Atopic Dermatitis"
# The predictor condition used to build condition cohort
condition_2_name = "Chronic Sinusitis"

# %% [markdown]
# <div style="border: 2px solid #2E86C1; padding: 20px; border-radius: 10px; margin: 20px 0; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#
# <div style="font-size: 17px; text-align: center; width: 55%; margin: 40px auto 20px auto; line-height: 1.6; color: #333;">
#
# Inspect the <strong>first 5 rows</strong> of the <code>case_df</code> dataframe and determine its <strong>dimensions</strong>.
#
# </div>
#
# <div style="text-align: center; margin: 10px auto; width: 70%; font-size: 17px; background-color: #e6f2ff; padding: 15px; border-radius: 6px; line-height: 1.6; border: 1px solid #2E86C1;">
# <b>Note:</b> To examine other dataframes, replace <code>case_df</code> with the desired dataframe name, such as <code>control_df</code> or <code>condition_df</code>.
# </div>
#
# </div>

# %%
# Displaying the head and shape of the dataframe
print(case_df.shape)
case_df.head()
# Out:
# (300, 5)
#    person_id sex_at_birth             date_of_birth  \
# 0          1         Male 1993-08-30 14:05:06+00:00
# 1          2       Female 1952-07-02 04:09:42+00:00
# 2          3       Female 1948-08-14 12:33:58+00:00
# 3          4         Male 1951-04-10 19:06:24+00:00
# 4          5         Male 1949-11-20 13:21:36+00:00
#
#                         race               ethnicity
# 0  Black or African American  Not Hispanic or Latino
# 1                      White      Hispanic or Latino
# 2  Black or African American  Not Hispanic or Latino
# 3  Black or African American  Not Hispanic or Latino
# 4                      Asian  Not Hispanic or Latino

# %% [markdown]
# ---
# <div style="text-align: center; margin-bottom: 25px; background-color: #E6FFE6; padding: 10px; border-radius: 10px;">
#
# <a id='pssection_5'></a>
#
# <h1 style="color: #2E86C1; font-weight: bold;">5. Creating a Column for the Outcome 🖋️</h1>
#
# </div>
#
# <div style="border: 2px solid #2E86C1; padding: 20px; border-radius: 10px; margin: 20px 0; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#
# <div style="font-size: 17px; text-align: center; width: 80%; margin: 20px auto; line-height: 1.6; color: #333;">
#
# In this guide, <strong>condition 1</strong> is treated as the <code>outcome</code> and used to define your <strong>case and control cohorts</strong>.
#
# Both <code>case_df</code> and <code>control_df</code> are constructed based on the presence or absence of the outcome. As we'll be merging these dataframes later, it's crucial to <strong>introduce a new column</strong> distinguishing between cases and controls.
#
# This new column, termed <code>outcome</code>, will be assigned a value of <code>1</code> for the case group and <code>0</code> for the control group.
#
# Unlike in R, logistic regression in Python necessitates that the `outcome` column consists of integers; it does not support categorical types. To accommodate this, we will generate an additional column, `outcome_f`, populated with categorical variables that have more descriptive labels for cases/controls.
#
# </div>
#
# </div>

# %%
# Assign all cases with the value 1 in a new column called 'outcome'
case_df['outcome'] = 1

# Assign all controls with the value 0 to same column
control_df['outcome'] = 0

# No factors in Python, so create column with labels
case_df['outcome_f'] = condition_1_name
control_df['outcome_f'] = f'No {condition_1_name}'

# %% [markdown]
# ---
# <div style="text-align: center; margin-bottom: 25px; background-color: #E6FFE6; padding: 10px; border-radius: 10px;">
#
# <a id='pssection_6'></a>
#
# <h1 style="color: #2E86C1; font-weight: bold;">6. Creating a Column for the Predictor 🖋️</h1>
#
# </div>
#
# <div style="border: 2px solid #2E86C1; padding: 20px; border-radius: 10px; margin: 20px 0; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#
# <div style="font-size: 17px; text-align: center; width: 80%; margin: 20px auto; line-height: 1.6; color: #333;">
#
# In this guide, <strong>condition 2</strong> is viewed as the <code>predictor</code> and used to define your <strong>condition cohort</strong>.
#
# We'll establish a new column within the <code>condition_df</code> dataframe to represent the this value. This new column, named <code>predictor</code>, will assign `condition_2_name` to each entry.
#
# </div>
#
# </div>

# %%
# Assign 1 to all persons in a new column called 'predictor'
condition_df['predictor'] = condition_2_name

print(condition_df.shape)
condition_df.head()
# Out:
# (290, 2)
#    person_id          predictor
# 0        141  Chronic Sinusitis
# 1        148  Chronic Sinusitis
# 2         61  Chronic Sinusitis
# 3        119  Chronic Sinusitis
# 4        130  Chronic Sinusitis

# %% [markdown]
# ---
# <div style="text-align: center; margin-bottom: 25px; background-color: #E6FFE6; padding: 10px; border-radius: 10px;">
#
# <a id='pssection_7'></a>
#
# <h1 style="color: #2E86C1; font-weight: bold;">7. Join the Data Frames 🔗</h1>
#
# </div>
#
#
#
# <div style="border: 2px solid #2E86C1; padding: 20px; border-radius: 10px; margin: 20px 0; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#
# <div style="font-size: 17px; text-align: center; width: 80%; margin: 20px auto; line-height: 1.6; color: #333;">
#
# <strong>1) Outer Join:</strong> This process appends the rows from `case_df` to `control_df` for all columns (they should have same column names).
#
# </div>
#
# <div style="font-size: 17px; text-align: center; width: 80%; margin: 20px auto; line-height: 1.6; color: #333;">
#
# <strong>2) Left Join:</strong> For each `person_id` in `merged_df`, a value of `condition_2_name` is assigned to the `predictor` column if the ID exists in `condition_df`. Otherwise, the `predictor` column value is set to `NA`.
#
# </div>
#
# </div>

# %%
# Full join the case and control dfs
merged_df = pandas.merge(case_df, control_df, how='outer') 

# Left join the condition_df
merged_df = pandas.merge(merged_df, condition_df, how='left', on='person_id')

# %% [markdown]
# ---
# <div style="text-align: center; margin-bottom: 25px; background-color: #E6FFE6; padding: 10px; border-radius: 10px;">
#
# <a id='pssection_8'></a>
#
# <h1 style="color: #2E86C1; font-weight: bold;">8. Replace NAs 🔄</h1>
#
# </div>
#
# <div style="border: 2px solid #2E86C1; padding: 20px; border-radius: 10px; margin: 20px 0; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#
# <div style="font-size: 17px; text-align: center; width: 80%; margin: 20px auto; line-height: 1.6; color: #333;">
#
# <strong>Reminder:</strong> Ensure that you fill in the `NA` values with `No condition_2_name`! The only column that should have `NA` values is the `predictor` column.
#
# </div>
#
# </div>

# %%
# This takes the NA values created from the left join and makes them the value 'No condition_2_name'.
merged_df = merged_df.fillna(f'No {condition_2_name}')

# %% [markdown]
# ---
# <div style="text-align: center; margin-bottom: 25px; background-color: #E6FFE6; padding: 10px; border-radius: 10px;">
#
# <a id='pssection_9'></a>
#
# <h1 style="color: #2E86C1; font-weight: bold;">9. Transform to Categorical Variables 🔡</h1>
#
# </div>
#
# <div style="border: 2px solid #2E86C1; padding: 20px; border-radius: 10px; margin: 20px 0; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#
# <div style="font-size: 17px; text-align: center; width: 80%; margin: 20px auto; line-height: 1.6; color: #333;">
#
# Our variables, namely `outcome_f`, `predictor`,`sex_at_birth`, `race`, and `ethnicity`, consist of character values. While logistic regression would inherently transform these into categorical values, proactively handling this conversion is advisable. By doing so, we can review and, if needed, reset the reference level. This foresight facilitates a clearer interpretation of odds ratios later in our analysis.
#
# </div>
#
# </div>
#
# <div style="text-align: center; margin: 10px auto; width: 70%; font-size: 17px; background-color: #e6f2ff; padding: 15px; border-radius: 6px; line-height: 1.6; border: 1px solid #2E86C1;">
# <b>Note:</b> The logistic regression reasoning does not apply to <code>outcome_f</code>, just doing it for the tables and plots later.
# </div>
#
# </div>

# %%
# Categorize the variables
merged_df['race'] = merged_df['race'].astype('category')
merged_df['ethnicity'] = merged_df['ethnicity'].astype('category')
merged_df['sex_at_birth'] = merged_df['sex_at_birth'].astype('category')
merged_df['predictor'] = merged_df['predictor'].astype('category')
merged_df['outcome_f'] = merged_df['outcome_f'].astype('category')

# %%
# Check levels..change variable name 'predictor' to relevel other demographics
print(merged_df['predictor'].cat.categories)

# Reset the predictor reference level to 'No {condition_2_name}'
merged_df['predictor'] = merged_df['predictor'].cat.reorder_categories([f"No {condition_2_name}", condition_2_name], ordered=True)
print(merged_df['predictor'].cat.categories)
# Out:
# Index(['Chronic Sinusitis', 'No Chronic Sinusitis'], dtype='object')
# Index(['No Chronic Sinusitis', 'Chronic Sinusitis'], dtype='object')

# %% [markdown]
# ---
# <div style="text-align: center; margin-bottom: 25px; background-color: #E6FFE6; padding: 10px; border-radius: 10px;">
#
# <a id='pssection_10'></a>
#
# <h1 style="color: #2E86C1; font-weight: bold;">10. Calculate Age 📅</h1>
#
# </div>
#
# <div style="border: 2px solid #2E86C1; padding: 20px; border-radius: 10px; margin: 20px 0; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#
# <div style="font-size: 17px; text-align: center; width: 80%; margin: 20px auto; line-height: 1.6; color: #333;">
#
# To compute the age at the time of primary consent, refer to the [User Support Hub](https://support.researchallofus.org/hc/en-us/articles/13176125767188-How-to-find-participant-enrollment-data). The link provides the necessary SQL code to fetch the `person_id` alongside the corresponding `primary_consent_date` for all participants in the All of Us database. For accurate age calculation, replace `today` with an appropriate variable name and substitute `Sys.Date()` with the provided SQL code.
#
# This will give us a continuous `age` variable and a categorical `age_group` variable.
#
# </div>
#
# </div>

# %%
# Get today's date
today = datetime.now()

# Ensure the date_of_birth is in datetime format
merged_df['date_of_birth'] = pandas.to_datetime(merged_df['date_of_birth']).dt.date

# Calculate age in years
merged_df['age'] = (today - pandas.to_datetime(merged_df['date_of_birth'])) / np.timedelta64(1, 'D') / 365.25
merged_df['age'] = merged_df['age'].astype(int)

# Create age groups
bins = [18, 29, 39, 49, 59, 69, 79, 110]
labels = ['18-29', '30-39', '40-49', '50-59', '60-69', '70-79', '80+']
merged_df['age_group'] = pandas.cut(merged_df['age'], bins=bins, labels=labels)

# Remove unused categories
merged_df['age_group'] = merged_df['age_group'].cat.remove_unused_categories()

# %% [markdown]
# <div style="text-align: center; margin-bottom: 25px; background-color: #E6FFE6; padding: 10px; border-radius: 10px;">
#
# <a id='pssection_11'></a>
#
# <h1 style="color: #2E86C1; font-weight: bold;">11. Explore Cleaned Data 🔍</h1>
#
# </div>
#
# <div style="border: 2px solid #2E86C1; padding: 20px; border-radius: 10px; margin: 20px 0; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#
# <div style="font-size: 17px; text-align: center; width: 80%; margin: 20px auto; line-height: 1.6; color: #333;">
#
# Inspect the first 5 rows of `merged_df` and review its dimensions to understand the structure of the cleaned dataset.
#
# </div>
#
# </div>

# %%
merged_df.shape
merged_df.head()
# Out:
#    person_id sex_at_birth date_of_birth                       race  \
# 0          1         Male    1993-08-30  Black or African American
# 1          2       Female    1952-07-02                      White
# 2          3       Female    1948-08-14  Black or African American
# 3          4         Male    1951-04-10  Black or African American
# 4          5         Male    1949-11-20                      Asian
#
#                 ethnicity  outcome          outcome_f             predictor  \
# 0  Not Hispanic or Latino        1  Atopic Dermatitis     Chronic Sinusitis
# 1      Hispanic or Latino        1  Atopic Dermatitis  No Chronic Sinusitis
# 2  Not Hispanic or Latino        1  Atopic Dermatitis     Chronic Sinusitis
# 3  Not Hispanic or Latino        1  Atopic Dermatitis  No Chronic Sinusitis
# 4  Not Hispanic or Latino        1  Atopic Dermatitis  No Chronic Sinusitis
#
#    age age_group
# 0   30     30-39
# 1   71     70-79
# 2   75     70-79
# 3   72     70-79
# 4   74     70-79

# %% [markdown]
# <div style="text-align: center; margin-bottom: 20px; background-color: #E6FFE6; padding: 8px; border-radius: 8px;">
#
# <a id='pssubsection_11_1'></a>
#
# <h2 style="color: #2E86C1; font-weight: bold;">11.1 Numerical Summary 🧮</h2>
#
# </div>
#
# <div style="border: 2px solid #2E86C1; padding: 20px; border-radius: 10px; margin: 20px 0; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#
# <div style="font-size: 17px; text-align: center; width: 80%; margin: 20px auto; line-height: 1.6; color: #333;">
#
# This code outputs a count/mean table for the all the variables in the analysis. It performs a chi-square for counts and t-test for means.
#
# </div>
#
# </div>

# %%
# Some deprecation errors..ignore them
warnings.filterwarnings("ignore")

# Define labels for the columns
labels = {
    'sex_at_birth': 'Sex',
    'race': 'Race',
    'ethnicity': 'Ethnicity',
    'age': 'Age',
    'age_group': 'Age Group',
    'predictor': 'Predictor',
    'outcome_f': 'Outcome'
}

# Specify columns to be included in the table
columns = ['age', 'sex_at_birth', 'race', 'ethnicity', 'predictor', 'age_group']

# Specify categorical columns
categorical = ['sex_at_birth', 'race', 'ethnicity', 'predictor', 'age_group']

# Label reference categories
def append_ref_to_label(data, exclude_var=None):
    for column in data.columns:
        if pandas.api.types.is_categorical_dtype(data[column]) and column != exclude_var:
            categories = data[column].cat.categories
            new_categories = [f"{cat} (ref)" if i == 0 else cat for i, cat in enumerate(categories)]
            data[column] = data[column].cat.rename_categories(new_categories)
    return data

labelled_df = merged_df.copy()

append_ref_to_label(labelled_df, exclude_var=None)


# Create an instance of TableOne with the data
table = TableOne(labelled_df, columns=columns, categorical=categorical, groupby='outcome_f', rename=labels, pval=True, htest_name=True)

# Print the table
table
# Out:
#                                             Grouped by Outcome
#                                                        Missing      Overall Atopic Dermatitis (ref) No Atopic Dermatitis P-Value               Test
# n                                                                      1300                     300                 1000
# Age, mean (SD)                                               0  48.8 (16.9)             48.8 (16.7)          48.9 (16.9)   0.971  Two Sample T-test
# Sex, n (%)       Female (ref)                                0   632 (48.6)              147 (49.0)           485 (48.5)   0.931        Chi-squared
#                  Male                                            668 (51.4)              153 (51.0)           515 (51.5)
# Race, n (%)      Asian (ref)                                 0   442 (34.0)              104 (34.7)           338 (33.8)   0.102        Chi-squared
#                  Black or African American                       433 (33.3)              112 (37.3)           321 (32.1)
#                  White                                           425 (32.7)               84 (28.0)           341 (34.1)
# Ethnicity, n (%) Hispanic or Latino (ref)                    0   613 (47.2)              135 (45.0)           478 (47.8)   0.432        Chi-squared
#                  Not Hispanic or Latino                          687 (52.8)              165 (55.0)           522 (52.2)
# Predictor, n (%) No Chronic Sinusitis (ref)                  0  1010 (77.7)              122 (40.7)           888 (88.8)  <0.001        Chi-squared
#                  Chronic Sinusitis                               290 (22.3)              178 (59.3)           112 (11.2)
# Age Group, n (%) 18-29 (ref)                                 0   214 (16.5)               51 (17.0)           163 (16.3)   0.396        Chi-squared
#                  30-39                                           238 (18.3)               44 (14.7)           194 (19.4)
#                  40-49                                           214 (16.5)               58 (19.3)           156 (15.6)
#                  50-59                                           222 (17.1)               54 (18.0)           168 (16.8)
#                  60-69                                           230 (17.7)               53 (17.7)           177 (17.7)
#                  70-79                                           182 (14.0)               40 (13.3)           142 (14.2)

# %% [markdown]
# <div style="text-align: center; margin-bottom: 20px; background-color: #E6FFE6; padding: 8px; border-radius: 8px;">
#
# <a id='pssubsection_11_2'></a>
#
# <h2 style="color: #2E86C1; font-weight: bold;">11.2 Graphical Summaries 📊</h2>
#
# </div>
#
# <div style="text-align: center; margin-bottom: 15px; background-color: #E6FFE6; padding: 6px; border-radius: 6px;">
#
# <a id='pssubsection_11_2_1'></a>
#
# <h4 style="color: #2E86C1; font-weight: bold;">11.2.1 Density/Histogram Plot</h4>
#
# </div>
#
# <div style="border: 2px solid #2E86C1; padding: 20px; border-radius: 10px; margin: 20px 0; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#
# <div style="font-size: 17px; text-align: center; width: 80%; margin: 20px auto; line-height: 1.6; color: #333;">
# This provides a <strong>density/histogram plot of age</strong> in the case and control groups. For this template, <code>age</code> is the only numeric value.
#
# </div>
#
# </div>

# %%
# Separate plot by outcome groups
# Set height of plot
hist_grid = sns.FacetGrid(merged_df, col="outcome_f", height = 7)
# Create histogram..specify density as stat
hist_grid.map_dataframe(sns.histplot, x='age', stat="density", kde=True, hue='outcome_f')
# Set grouping label
hist_grid.set_titles("{col_name}")
# Set title
hist_grid.fig.suptitle("Distribution of Age By Case/Control")
# Set axis labels
hist_grid.set_axis_labels('Age', 'Density')

# %% [markdown]
# <div style="text-align: center; margin-bottom: 15px; background-color: #E6FFE6; padding: 6px; border-radius: 6px;">
#
# <a id='pssubsection_11_2_2'></a>
#
# <h4 style="color: #2E86C1; font-weight: bold;">11.2.2 Bar Plot</h4>
#
# </div>
#
# <div style="border: 2px solid #2E86C1; padding: 20px; border-radius: 10px; margin: 20px 0; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#
# <div style="font-size: 17px; text-align: center; width: 80%; margin: 20px auto; line-height: 1.6; color: #333;">
#
# This provides a <strong>bar plot of categorical values</strong> in the case and control groups. <strong>Replace the value</strong> assigned to <code>categorical_variable</code> with the column name you would like to observe (i.e. <font color="red">"sex_at_birth"</font>). Also, <strong>replace the name</strong> for <code>label</code> with the name you would like to display for the column in the graph (i.e. <font color="red">"Sex"</font>)
#
# </div>
#
# </div>

# %%
# Specify the column name for the categorical variable
categorical_variable = "sex_at_birth"
label = "Sex"


# Separate by outcome
perc_grid = sns.FacetGrid(merged_df, col="outcome_f", height = 7)
# Create histogram..specify percentage as stat
perc_grid.map_dataframe(sns.histplot, x=categorical_variable, stat="percent", hue=categorical_variable)
# Set grouping label
perc_grid.set_titles("{col_name}")
# Set title
perc_grid.fig.suptitle(f"Proportion of {label} By Case/Control")
# Set axis labels
perc_grid.set_axis_labels(label, 'Percent')

def annotate(ax):
    for p in ax.patches:
        if p.get_height() > 0:  # Add annotations only for bars with non-zero height
            percentage = '{:.1f}%'.format(p.get_height())
            x = p.get_x() + p.get_width() / 2
            y = p.get_y() + p.get_height() - 2
            ax.text(x, y, percentage, ha='center', va='bottom')

# Applying the annotation function to each axis
for ax in perc_grid.axes.flat:
    annotate(ax)

plt.show()

# %% [markdown]
# ---
# <div style="text-align: center; margin-bottom: 25px; background-color: #E6FFE6; padding: 10px; border-radius: 10px;">
#
# <a id='pssection_12'></a>
#
# <h1 style="color: #2E86C1; font-weight: bold;">12. Statistical Analysis 📈🧐</h1>
#
# </div>
#
# <div style="border: 2px solid #2E86C1; padding: 20px; border-radius: 10px; margin: 20px 0; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#
# <div style="font-size: 17px; text-align: center; width: 80%; margin: 20px auto; line-height: 1.6; color: #333;">
#
# **You have the option to run all the tests listed below, or simply select the specific one you need and execute the cells below it.**
#
# </div>
#
# </div>
#
# <div style="text-align: center; margin-bottom: 20px; background-color: #E6FFE6; padding: 8px; border-radius: 8px;">
#
# <a id='pssubsection_12_1'></a>
#
# <h2 style="color: #2E86C1; font-weight: bold;">12.1 Pearson's Chi-Square Test</h2>
#
# </div>
#
# <div style="border: 2px solid #2E86C1; padding: 20px; border-radius: 10px; margin: 20px 0; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#
# <div style="font-size: 17px; text-align: center; width: 80%; margin: 20px auto; line-height: 1.6; color: #333;">
#
# A **2x2 contingency table** named `chisq_table` is constructed to display the counts for each predictor and outcome category. Subsequently, a **Pearson's Chi-Square Test** is conducted using this contingency table to analyze the relationship between the predictor and outcome variables.
#
# </div>
#
# </div>

# %%
# Replace the word 'predictor' with the column name you would like to test against the outcome.
chisq_table = pandas.crosstab(merged_df['outcome_f'], 
            merged_df['predictor'],
            margins = False)
chisq_table
# Out:
# predictor             No Chronic Sinusitis  Chronic Sinusitis
# outcome_f
# Atopic Dermatitis                      122                178
# No Atopic Dermatitis                   888                112

# %%
# Perform the chi-squared test
chi2_contingency(chisq_table, correction=False)
# Out:
# Chi2ContingencyResult(statistic=308.4871742346649, pvalue=4.664296627996274e-69, dof=1, expected_freq=array([[233.07692308,  66.92307692],
#        [776.92307692, 223.07692308]]))

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <b>Interpreting Chi-Square Test of Independence Output:</b>
#     <ul>
#         <li><b>statistic (308.487):</b> A high value, indicating a significant difference between observed and expected frequencies.</li>
#         <li><b>p-value (4.664e-69):</b> Extremely low, suggesting a very strong evidence against the null hypothesis of no association between the variables.</li>
#         <li><b>df (1):</b> Degrees of freedom; indicates a 2x2 table was used.</li>
#         <li><b>expected_freq ([233.07692308,  66.92307692],[776.92307692, 223.07692308]):</b> Expected frequencies [a,b][c,d].</li>
#     </ul>
#     <b>Conclusion:</b> The test provides strong evidence of a significant association between the <code>outcome</code> and <code>predictor</code> being analyzed.
# </div>

# %% [markdown]
# <div style="text-align: center; margin-bottom: 20px; background-color: #E6FFE6; padding: 8px; border-radius: 8px;">
#
# <a id='pssubsection_12_2'></a>
#
# <h2 style="color: #2E86C1; font-weight: bold;">12.2 Variance Test and T-Test</h2>
#
# </div>
#
# <div style="border: 2px solid #2E86C1; padding: 20px; border-radius: 10px; margin: 20px 0; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#
# <div style="font-size: 17px; text-align: center; width: 80%; margin: 20px auto; line-height: 1.6; color: #333;">
#
# A **variance test** and a **t-test** are ran below for `age`, a quantitative variable. This compares the **mean age** between the case and control groups.
#
# The Levene's Test is slightly different from the F-Test in the R notebook.  Levene's test assesses the equality of variances in different groups by analyzing the deviation of each observation from the group mean or median. Unlike some variance tests, it is not based on the ratio of variances, making it more robust to certain assumptions, such as normality.
#
# </div>
#
# </div>

# %%
# Split into case and control groups
case_group = merged_df[merged_df['outcome'] == 0]
control_group = merged_df[merged_df['outcome'] == 1]
# Run Levene's test
stats.levene(case_group['age'], control_group['age'], center='mean')
# Out:
# LeveneResult(statistic=0.6423027602343377, pvalue=0.423024846769569)

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <b>Interpreting Levene's Test Output:</b>
#     <ul>
#         <li><b>statistic (0.689):</b> A value representing the significance of the difference in variability among groups. Lower values suggest that variances are more similar.</li>
#         <li><b>p-value (0.407):</b> A value greater than common significance levels (e.g., 0.05), suggesting insufficient evidence to reject the null hypothesis of equal variances.</li>
#     </ul>
#     <b>Conclusion:</b> The test suggests that the variances across groups are similar, and there's no strong evidence to conclude otherwise.
# </div>

# %%
# Run ttest
stats.ttest_ind(case_group['age'], control_group['age'], equal_var=True)
# Out:
# TtestResult(statistic=0.03568878905806828, pvalue=0.9715359973561468, df=1298.0)

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <b>Interpreting T-test Output:</b>
#     <ul>
#         <li><b>statistic (0.0498):</b> A value close to zero, indicating that the difference between the group means is small.</li>
#         <li><b>p-value (0.960):</b> A high value, suggesting that the observed data is quite consistent with the null hypothesis of equal group means.</li>
#     </ul>
#     <b>Conclusion:</b> There is no strong evidence to reject the null hypothesis; the means of the two groups are not statistically significantly different.
# </div>

# %% [markdown]
# <div style="text-align: center; margin-bottom: 20px; background-color: #E6FFE6; padding: 8px; border-radius: 8px;">
#
# <a id='pssubsection_12_3'></a>
#
# <h2 style="color: #2E86C1; font-weight: bold;">12.3 Logistic Regressions</h2>
#
# </div>
#
# <div style="text-align: center; margin-bottom: 15px; background-color: #E6FFE6; padding: 6px; border-radius: 6px;">
# <a id='pssubsection_12_3_1'></a>
# <h4 style="color: #2E86C1; font-weight: bold;">12.3.1 Unadjusted Logistic Regression</h4>
# </div>
#
# <div style="border: 2px solid #2E86C1; padding: 20px; border-radius: 10px; margin: 20px 0; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
# <div style="font-size: 17px; text-align: center; width: 80%; margin: 20px auto; line-height: 1.6; color: #333;">
#
# Welcome to the section on **Unadjusted Logistic Regression**. This statistical method, also known as "simple" or "bivariate" logistic regression, serves as a foundational approach to understand the relationship between a binary response variable and a single predictor.
#
# Here are some key components to grasp:
#
# - **Response Variable:** At its core, this method requires a binary outcome. Think of results like Yes/No, 1/0, or Success/Failure.
#
# - **Predictor Variable:** This can be either categorical, such as gender, or continuous like age. For instance, one might be investigating the effect of gender on the odds of developing a certain disease.
#
# - **Odds Ratio (OR):** A crucial metric in logistic regression. The OR informs us about the change in odds of the outcome for a one-unit increase in the predictor. An OR of 1 indicates no effect of the predictor on the outcome. An OR greater than 1 means the outcome becomes more likely as the predictor increases, and an OR less than 1 suggests the outcome becomes less likely.
#
# Dive in, explore, and use this method to draw meaningful conclusions from your data.
#
# </div>
# </div>

# %%
# Run logistic regression
unadj_reg = smf.logit("outcome ~ predictor", data = merged_df).fit()
# Show results
unadj_reg.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.435093
#          Iterations 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                outcome   No. Observations:                 1300
# Model:                          Logit   Df Residuals:                     1298
# Method:                           MLE   Df Model:                            1
# Date:                Fri, 02 Feb 2024   Pseudo R-squ.:                  0.1946
# Time:                        11:55:18   Log-Likelihood:                -565.62
# converged:                       True   LL-Null:                       -702.27
# Covariance Type:            nonrobust   LLR p-value:                 2.179e-61
# ==================================================================================================
#                                      coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         -1.9850      0.097    -20.558      0.000      -2.174      -1.796
# predictor[T.Chronic Sinusitis]     2.4482      0.154     15.846      0.000       2.145       2.751
# ==================================================================================================
# """

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <b>Interpreting the Logistic Regression Output:</b>
#     <ul>
#         <li><b>Pseudo R-squared (0.1946):</b> A measure to compare the fit of the model to a null model. It doesn’t have a straightforward interpretation as the proportion of variance explained, but rather it gives us an idea of the improvement of our model over a null model.</li>
#         <li><b>Log-Likelihood (-565.62):</b> Representing the log of the likelihood function at its maximum. These will always be negative, and a higher (closer to 0) value indicates a better model fit.</li>
#         <li><b>LLR p-value (2.179e-61):</b> A low p-value, suggesting that the model is a better fit than a null model with no predictors.</li>
#         <li><b>coef:</b>
#             <ul>
#                 <li><code>Intercept</code>: <b>-1.9850</b>, the log-odds of the outcome when all predictors are zero.</li>
#                 <li><code>predictor[T.Chronic Sinusitis]</code>: <b>2.4482</b>, the change in log-odds of the outcome for a unit change in the predictor. It's statistically significant with a p-value close to zero.</li>
#             </ul>
#         </li>
#         <li><b>std err (0.154):</b> The standard error of the coefficients. It is a measure of the accuracy of the coefficients.</li>
#         <li><b>z (15.846):</b> The z-score, calculated as the coefficient divided by the standard error. It is used to test the hypothesis that the coefficient is different from zero.</li>
#         <li><b>P>|z| (0.000):</b> The p-value associated with the z-score; this one is highly significant. It helps you infer the statistical significance of each coefficient if less than 0.05.</li>
#         <li><b>[0.025 0.975] (2.145, 2.751):</b> The 95% confidence interval for the coefficient. Does not span 0, so it is statistically significant.</li>
#     </ul>
#     <b>Conclusion:</b> The logistic regression model converged successfully, and the predictor <code>Chronic Sinusitis</code> is a significant factor in predicting the outcome, with the model providing a better fit than a null model.
# </div>

# %% [markdown]
# <div style="text-align: center; margin-bottom: 15px; background-color: #E6FFE6; padding: 6px; border-radius: 6px;">
#
# <a id='pssubsection_12_3_2'></a>
#
# <h4 style="color: #2E86C1; font-weight: bold;">12.3.2 Unadjusted Odds Ratio and Confidence Interval</h4>
#
# </div>
#
# <div style="border: 2px solid #2E86C1; padding: 20px; border-radius: 10px; margin: 20px 0; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#
# <div style="font-size: 17px; text-align: center; width: 80%; margin: 20px auto; line-height: 1.6; color: #333;">
#
# **Interpreting the Unadjusted Logistic Regression Results:**
#
# **Chronic Sinusitis:** Those with the `predictor` Chronic Sinusitis have 11.57 [8.55-15.66] times higher odds of having the `outcome` Atopic Dermatitis compared to those without Chronic Sinusitis.
#
# <div style="font-size: 16px; text-align: center; width: 90%; margin: 20px auto; color: #555;">
# <b>Note:</b> Confidence intervals that span over 1 suggest the result isn't statistically significant at the standard 0.05 level.
# </div>
# </div>
# </div>

# %%
# Create OR column
unadj_odds = pandas.DataFrame(np.exp(unadj_reg.params), columns= ['OR'])
# Create CI column
unadj_odds[['2.5%', '97.5%']] = np.exp(unadj_reg.conf_int())
# Print OR and CI
unadj_odds
# Out:
#                                        OR      2.5%      97.5%
# Intercept                        0.137387  0.113700   0.166010
# predictor[T.Chronic Sinusitis]  11.567916  8.545684  15.658978

# %% [markdown]
# <div style="text-align: center; margin-bottom: 15px; background-color: #E6FFE6; padding: 6px; border-radius: 6px;">
#
# <a id='pssubsection_12_3_3'></a>
#
# <h4 style="color: #2E86C1; font-weight: bold;">12.3.3 Adjusted Logistic Regression</h4>
#
# </div>
#
# <div style="border: 2px solid #2E86C1; padding: 20px; border-radius: 10px; margin: 20px 0; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
# <div style="font-size: 17px; text-align: center; width: 80%; margin: 20px auto; line-height: 1.6; color: #333;">
#
# Building on the previous unadjusted analysis, the **Adjusted Logistic Regression** now incorporates multiple predictors, allowing us to control for potential confounders. This updated approach includes additional variables like **sex, age_group, race, and ethnicity**.
#
# **Key Points:**
#
# - **Multiple Predictor Variables:** By integrating several predictors, both categorical and continuous, this adjusted analysis enables more in-depth insights, like the combined influence of age with other demographics.
#
# - **Odds Ratio (OR):** Essential in adjusted analysis, each OR represents the effect of a predictor while holding other variables constant. OR values inform whether a predictor increases, decreases, or has no effect on the likelihood of the outcome.
#
# </div>
# </div>

# %%
# Run logistic regression
adj_reg = smf.logit("outcome ~ predictor + ethnicity + age_group + sex_at_birth + race", data = merged_df).fit()
# Show results
adj_reg.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.430893
#          Iterations 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                outcome   No. Observations:                 1300
# Model:                          Logit   Df Residuals:                     1289
# Method:                           MLE   Df Model:                           10
# Date:                Fri, 02 Feb 2024   Pseudo R-squ.:                  0.2024
# Time:                        11:55:18   Log-Likelihood:                -560.16
# converged:                       True   LL-Null:                       -702.27
# Covariance Type:            nonrobust   LLR p-value:                 3.369e-55
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                              -1.8978      0.244     -7.786      0.000      -2.376      -1.420
# predictor[T.Chronic Sinusitis]          2.4700      0.157     15.771      0.000       2.163       2.777
# ethnicity[T.Not Hispanic or Latino]     0.1157      0.152      0.760      0.447      -0.183       0.414
# age_group[T.30-39]                     -0.4999      0.267     -1.873      0.061      -1.023       0.023
# age_group[T.40-49]                      0.1987      0.257      0.773      0.440      -0.305       0.702
# age_group[T.50-59]                      0.0426      0.258      0.165      0.869      -0.463       0.549
# age_group[T.60-69]                     -0.1271      0.259     -0.491      0.623      -0.634       0.380
# age_group[T.70-79]                     -0.1163      0.276     -0.421      0.674      -0.657       0.425
# sex_at_birth[T.Male]                   -0.0264      0.152     -0.174      0.862      -0.324       0.271
# race[T.Black or African American]       0.0351      0.182      0.193      0.847      -0.321       0.391
# race[T.White]                          -0.2386      0.190     -1.256      0.209      -0.611       0.134
# =======================================================================================================
# """

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <b>Interpreting the Updated Logistic Regression Output:</b>
#     <ul>
#         <li><b>Model:</b> The outcome is predicted by the <code>predictor</code>, along with other variables including <code>ethnicity</code>, <code>age_group</code>, <code>sex_at_birth</code>, and <code>race</code> in a binary logistic regression using the dataset.</li>
#         <li><b>Pseudo R-squared (0.2020):</b> A measure to compare the fit of the model to a null model. Higher than unadjusted model, so better fit.</li>
#         <li><b>Log-Likelihood (-560.38):</b> Representing the log of the likelihood function at its maximum. These will always be negative, and a higher (closer to 0) value indicates a better model fit.</li>
#         <li><b>LLR p-value (4.182e-55):</b> A low p-value, suggesting that the model is a better fit than a null model with no predictors.</li>
#         <li><b>coef:</b>
#         <li><code>predictor[T.Chronic Sinusitis]</code>: Highly significant with a p-value close to zero.</li>
#         <li><code>ethnicity[T.Not Hispanic or Latino]</code>: Not significant with a p-value of 0.439.</li>
#         <li><code>age_group</code>:
#                 <ul>
#                     <li><code>age_group[T.30-39]</code>: Marginally significant with a p-value of 0.061.</li>
#                     <li><code>age_group[T.40-49]</code>: Not significant with a p-value of 0.458.</li>
#                     <li><code>age_group[T.50-59]</code>: Not significant with a p-value of 0.931.</li>
#                     <li><code>age_group[T.60-69]</code>: Not significant with a p-value of 0.677.</li>
#                     <li><code>age_group[T.70-79]</code>: Not significant with a p-value of 0.637.</li>
#                 </ul>
#             </li>
#         <li><code>sex_at_birth[T.Male]</code>: Not significant with a p-value of 0.901.</li>
#         <li><code>race</code>:
#                 <ul>
#                     <li><code>race[T.Black or African American]</code>: Not significant with a p-value of 0.846.</li>
#                     <li><code>race[T.White]</code>: Not significant with a p-value of 0.202.</li>
#                 </ul>
#             </li>
# </ul>
# <b>Conclusion:</b> Among the predictors, <code>predictor[T.Chronic Sinusitis]</code> is the most significant in predicting the outcome. Other variables such as ethnicity, age_group, sex_at_birth, and race are not as strongly associated with the outcome in this model.
# </div>

# %% [markdown]
# <div style="text-align: center; margin-bottom: 15px; background-color: #E6FFE6; padding: 6px; border-radius: 6px;">
#
# <a id='pssubsection_12_3_4'></a>
#
# <h4 style="color: #2E86C1; font-weight: bold;">12.3.4 Adjusted Odds Ratio and Confidence Interval</h4>
#
# </div>
#
# <div style="border: 2px solid #2E86C1; padding: 20px; border-radius: 10px; margin: 20px 0; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#
# <div style="font-size: 17px; text-align: center; width: 80%; margin: 20px auto; line-height: 1.6; color: #333;">
#
# **Interpreting the Adjusted Logistic Regression Results:**
#
# - **Chronic Sinusitis:** Individuals with the `predictor` have about 11.81 [8.69-16.05] times higher odds of having the outcome compared to those without the `predictor`.
#
# - **Ethnicity:** Compared to `Hispanic or Latino` individuals, those who are `Not Hispanic or Latino` exhibit 1.12 [0.83-1.52] times higher odds of having the outcome, but this is not statistically significant.
#
# - **Age Group:** When compared to the reference age group `18-29`:
#
#     - **Age Group 30-39:** This group has 0.61 [0.36-1.02] times lower odds of having the outcome, which is not statistically significant.
#
#     - **Age Group 40-49:** This group has 1.21 [0.73-2.01] times higher odds of having the outcome, which is not statistically significant.
#
#     - **Age Group 50-59:** This group has 1.02 [0.62-1.68] times higher odds of having the outcome, which is not statistically significant.
#
#     - **Age Group 60-69:** This group has 0.90 [0.54-1.49] times lower odds of having the outcome, which is not statistically significant.
#
#     - **Age Group 70-79:** This group has 0.88 [0.51-1.51] times lower odds of having the outcome, which is not statistically significant.
#
# - **Sex at Birth:** Males have 0.98 [0.73-1.32] times lower odds of having the outcome compared to females, which is not statistically significant.
#
# - **Race:** Compared to the reference group `Asian`:
#
#     - **Black or African American:** The odds are 1.03 [0.73-1.48], which is not statistically significant.
#
#     - **White:** The odds ratio is 0.78 [0.54-1.14], suggesting lower odds, but this is not statistically significant.
#
# <div style="font-size: 16px; text-align: center; width: 90%; margin: 20px auto; color: #555;">
# <b>Notes:</b> <br>
#     <strong>1.</strong> Confidence intervals traversing the value of 1 imply non-significance at the conventional 0.05 level. <br>
#     <strong>2.</strong> In these adjusted models, all other variables are held constant, implying the interpretation for each factor is isolated from the influence of others.
# </div>
#
# </div>
# </div>

# %%
# Create OR column
adj_odds = pandas.DataFrame(np.exp(adj_reg.params), columns= ['OR'])
# Create CI column
adj_odds[['2.5%', '97.5%']] = np.exp(adj_reg.conf_int())
# Print OR and CI
adj_odds
# Out:
#                                             OR      2.5%      97.5%
# Intercept                             0.149901  0.092966   0.241705
# predictor[T.Chronic Sinusitis]       11.822297  8.697460  16.069829
# ethnicity[T.Not Hispanic or Latino]   1.122655  0.833077   1.512890
# age_group[T.30-39]                    0.606580  0.359521   1.023414
# age_group[T.40-49]                    1.219790  0.737068   2.018658
# age_group[T.50-59]                    1.043512  0.629172   1.730715
# age_group[T.60-69]                    0.880678  0.530331   1.462471
# age_group[T.70-79]                    0.890223  0.518161   1.529443
# sex_at_birth[T.Male]                  0.973932  0.723110   1.311755
# race[T.Black or African American]     1.035744  0.725635   1.478384
# race[T.White]                         0.787707  0.542852   1.143004

# %% [markdown]
# <div style="text-align: center; margin-bottom: 15px; background-color: #E6FFE6; padding: 6px; border-radius: 6px;">
# <a id='pssubsection_12_3_5'></a>
# <h4 style="color: #2E86C1; font-weight: bold;">12.3.5 Summary of Logistic Regressions</h4>
# </div>
#
# <div style="border: 2px solid #2E86C1; padding: 20px; border-radius: 10px; margin: 20px 0; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
# <div style="font-size: 17px; text-align: center; width: 80%; margin: 20px auto; line-height: 1.6; color: #333;">
#
# This is the final table for the logistic regressions. It shows the unadjusted and adjusted odds ratio for the `predictor` in your analysis.
#
# </div>
# </div>

# %%
# Create table with unadjusted and adjusted OR (CI)
final_table = pandas.DataFrame({
    'Predictor': condition_2_name,
    'Univariate OR (95% CI)': [f"{unadj_odds['OR'][1]:.2f} ({unadj_odds['2.5%'][1]:.2f} - {unadj_odds['97.5%'][1]:.2f})"],
    'Multivariate OR (95% CI)': [f"{adj_odds['OR'][1]:.2f} ({adj_odds['2.5%'][1]:.2f} - {adj_odds['97.5%'][1]:.2f})"],
    })

# Print table without index 
final_table.index=[''] * len(final_table)
final_table
# Out:
#           Predictor Univariate OR (95% CI) Multivariate OR (95% CI)
#   Chronic Sinusitis   11.57 (8.55 - 15.66)     11.82 (8.70 - 16.07)

# %% [markdown]
# <div style="text-align: center; margin-bottom: 15px; background-color: #E6FFE6; padding: 6px; border-radius: 6px;">
# <a id='pssubsection_12_3_6'></a>
# <h4 style="color: #2E86C1; font-weight: bold;">12.3.6 Forest Plot</h4>
# </div>
#
# <div style="border: 2px solid #2E86C1; padding: 20px; border-radius: 10px; margin: 20px 0; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
# <div style="font-size: 17px; text-align: center; width: 80%; margin: 20px auto; line-height: 1.6; color: #333;">
#
# This forest plot displays the adjusted ORs for all categorical variables in the analysis.
#
# </div>
# </div>

# %%
forest_table = adj_odds[1:][:]
forest_table['label'] = [v.split('.')[1].split(']')[0] for v in list(forest_table.index)]

# %%
# Create the forest plot
ax = fp.forestplot(forest_table,  # the dataframe with results data
                   estimate="OR",  # column containing estimated effect size
                   ll="2.5%", hl="97.5%",  # columns containing confidence interval lower and higher limits
                   varlabel="label",
                   ylabel="Confidence interval",
                   xlabel="Odds Ratio",
                   xticks=[-1, 1, 5, 10, 15])

# Add a vertical line at x=1
ax.axvline(x=1, color='black', linestyle='--', linewidth=2)  # Customize color, linestyle, and linewidth as needed

# Optionally, if you want to try to remove or hide the automatic line at x=0, you can do the following:
ax.axvline(x=0, color='white', linewidth=2)  # Attempt to cover it with a line the color of the background

# Show the plot
plt.show()
